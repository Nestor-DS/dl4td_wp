# %% [markdown]
# Contexto:
#
# El dataset se llama 'drinking_water_potability.csv', el cual contiene las columnas: ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity', Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability']. (Ya no contiene valores nan).
# La variable objetivo es 'Potability' con valores 0 y 1, tiene 1998 valores de 0 y 1278 valores de 1.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import resample
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import tensorflow as tf
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('../drinking_water_potability.csv')
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
df['Potability'].value_counts().plot(kind='bar')
plt.xlabel('Potability')
plt.ylabel('Count')
plt.title('Potability Value Counts')
plt.show()
print(df['Potability'].value_counts())
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %% [markdown]
# ## **Balanceo de clases**

# %%
from sklearn.utils import resample

df_majority = df[df.Potability==0]
df_minority = df[df.Potability==1]

df_majority_downsampled = resample(df_majority, replace=False, n_samples=len(df_minority), random_state=42)

df_balanced = pd.concat([df_majority_downsampled, df_minority])

# %%
df_balanced['Potability'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Potability'>

# %% [markdown]
# ## **Predictorias y targets**

# %%
X = df_balanced.drop('Potability', axis=1)
y = df_balanced['Potability']

# %%
X

# %% [markdown]
# ## **Normalización de datos**

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
columns = X.columns
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=columns)

# %%
X_scaled
# Out:
#             ph  Hardness    Solids  Chloramines   Sulfate  Conductivity  \
# 0     0.453314  0.578391  0.510515     0.326894  0.627033      0.731939
# 1     0.569061  0.639323  0.608408     0.494166  0.581699      0.308083
# 2     0.635780  0.351132  0.036647     0.692809  0.622034      0.637776
# 3     0.534596  0.489223  0.088150     0.501945  0.695601      0.339256
# 4     0.473191  0.484747  0.363233     0.792405  0.405825      0.321941
# ...        ...       ...       ...          ...       ...           ...
# 2551  0.333535  0.530482  0.775947     0.533436  0.656047      0.654856
# 2552  0.569439  0.530016  0.279263     0.603473  0.581699      0.400510
# 2553  0.690415  0.465486  0.539101     0.547807  0.581699      0.475680
# 2554  0.367986  0.664407  0.191490     0.465860  0.581699      0.420318
# 2555  0.574382  0.535635  0.280484     0.560259  0.581699      0.277130
#
#       Organic_carbon  Trihalomethanes  Turbidity
# 0           0.554831         0.559872   0.480353
# 1           0.584415         0.575066   0.269723
# 2           0.474203         0.295386   0.150810
# 3           0.737055         0.563899   0.367187
# 4           0.394908         0.502662   0.395475
# ...              ...              ...        ...
# 2551        0.471422         0.505178   0.561031
# 2552        0.713647         0.502662   0.248921
# 2553        0.356318         0.532441   0.344338
# 2554        0.361553         0.598427   0.613032
# 2555        0.561960         0.608876   0.155703
#
# [2556 rows x 9 columns]

# %% [markdown]
# ## **Separación de train y test**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **Función para medir el error**

# %%
from sklearn.metrics import roc_auc_score

def mide_error(model_name, y_pred):
    auc = roc_auc_score(y_test, y_pred)
    print(f'{model_name} AUC: {auc:.4f}')

# %% [markdown]
# # **Modelo**

# %% [markdown]
# ## **MLP**

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100, 100),     # Tamaño de las capas ocultas
    activation='relu',                  # Función de activación de las neuronas
    solver='adam',                      # Algoritmo de optimización
    alpha=0.0001,                       # Término de regularización L2
    batch_size='auto',                  # Tamaño del lote de entrenamiento
    learning_rate='constant',           # Tasa de aprendizaje
    learning_rate_init=0.001,           # Tasa de aprendizaje inicial
    power_t=0.5,                        # Exponente para la tasa de aprendizaje inversa
    max_iter=200,                       # Número máximo de iteraciones
    shuffle=True,                       # Barajar muestras en cada iteración
    random_state=42,                    # Semilla aleatoria para reproducibilidad
    tol=0.0001,                         # Tolerancia para la convergencia
    verbose=False,                      # Imprimir mensajes de progreso
    warm_start=False,                   # Inicialización cálida
    momentum=0.9,                       # Término de impulso para el descenso del gradiente
    nesterovs_momentum=True,            # Usar momentum de Nesterov
    early_stopping=False,               # Detener el entrenamiento temprano si no mejora
    validation_fraction=0.1,            # Fracción de datos utilizados para la validación
    beta_1=0.9,                         # Tasa de decaimiento exponencial para estimaciones de primer orden
    beta_2=0.999,                       # Tasa de decaimiento exponencial para estimaciones de segundo orden
    epsilon=1e-08,                      # Valor pequeño para la estabilidad numérica
    n_iter_no_change=10,                # Número máximo de iteraciones sin mejora
    max_fun=15000                       # Número máximo de evaluaciones de la función objetivo
)

mlp.fit(X_train, y_train)

y_pred = mlp.predict_proba(X_test)[:, 1]

mide_error('MLP', y_pred)
# Out:
# MLP AUC: 0.6647
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## **AdaBoostClassifier (Decision tree) + MLP con Voting Classifier**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
mlp = MLPClassifier(random_state=42)
hist_gradient_boosting = HistGradientBoostingClassifier(random_state=42)

# %%
ensemble_model = VotingClassifier(estimators=[('mlp', mlp), ('hgb', hist_gradient_boosting)], voting='soft')

# %%
param_grid = {
    'mlp__hidden_layer_sizes': [(100,), (100, 100)],
    'mlp__alpha': [0.0001, 0.001, 0.01],
    'mlp__learning_rate_init': [0.001, 0.01],
    'hgb__max_iter': [100, 200],
    'hgb__max_depth': [5, 10]
}

# %%
grid_search = GridSearchCV(ensemble_model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=VotingClassifier(estimators=[('mlp',
#                                                      MLPClassifier(random_state=42)),
#                                                     ('hgb',
#                                                      HistGradientBoostingClassifier(random_state=42))],
#                                         voting='soft'),
#              param_grid={'hgb__max_depth': [5, 10], 'hgb__max_iter': [100, 200],
#                          'mlp__alpha': [0.0001, 0.001, 0.01],
#                          'mlp__hidden_layer_sizes': [(100,), (100, 100)],
#                          'mlp__learning_rate_init': [0.001, 0.01]},
#              scoring='accuracy')

# %%
best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

# %%
y_pred = best_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Exactitud del mejor modelo en el conjunto de prueba:", accuracy)
print("Mejores hiperparámetros:", best_params)
# Out:
# Exactitud del mejor modelo en el conjunto de prueba: 0.6844512195121951
# Mejores hiperparámetros: {'hgb__max_depth': 10, 'hgb__max_iter': 100, 'mlp__alpha': 0.001, 'mlp__hidden_layer_sizes': (100,), 'mlp__learning_rate_init': 0.01}

# %% [markdown]
# **Encontrar mejores hiperparametros**

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neural_network import MLPClassifier
from scipy.stats import uniform

# Define el modelo MLP
mlp = MLPClassifier()

# Define la distribución de hiperparámetros a buscar
param_dist = {
    'hidden_layer_sizes': [(100,), (100, 100)],
    'alpha': uniform(0.0001, 0.01),
    'learning_rate_init': uniform(0.001, 0.01),
    'max_iter': [100, 200]
}

# Realiza la búsqueda aleatoria
random_search = RandomizedSearchCV(mlp, param_distributions=param_dist, n_iter=20, cv=5, scoring='accuracy')
random_search.fit(X_train, y_train)

# Obtiene el mejor modelo y los mejores hiperparámetros
best_model = random_search.best_estimator_
best_params = random_search.best_params_
# Out:
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print("Mejores hiperparámetros:", best_params)
print("Mejores hiperparámetros:", best_model)
# Out:
# Mejores hiperparámetros: {'alpha': 0.003132298023397408, 'hidden_layer_sizes': (100, 100), 'learning_rate_init': 0.006079821202913575, 'max_iter': 100}
# Mejores hiperparámetros: MLPClassifier(alpha=0.003132298023397408, hidden_layer_sizes=(100, 100),
#               learning_rate_init=0.006079821202913575, max_iter=100)

# %% [markdown]
# **MLP con mejores hiperparametros**

# %%
from sklearn.neural_network import MLPClassifier

best_model = MLPClassifier(alpha=0.004691546592834658,
                            learning_rate_init=0.009023557986183942,
                            max_iter=100,
                            random_state=42)

best_model.fit(X_train, y_train)  # Entrenar el modelo con los datos de entrenamiento

y_pred = best_model.predict(X_test)  # Realizar predicciones en los datos de prueba
# Out:
# c:\Users\nesto\anaconda3\envs\deep_learning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
mide_error('MLP', y_pred)
# Out:
# MLP AUC: 0.5941

# %% [markdown]
# **Ejemplo de RNN (Red Neuronal Recurrente):**

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

# %%
# Definir el modelo RNN
model = Sequential()

# Capa recurrente
model.add(SimpleRNN(32, input_shape=(None, 1), activation='relu'))

# Capa densa de salida
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))

# Imprimir la precisión en el conjunto de prueba
accuracy = history.history['val_accuracy'][-1]  # Obtiene la precisión en la última época
print("Precisión en el conjunto de prueba:", accuracy)
# Out:
# Epoch 1/100
# 82/82 [==============================] - 2s 8ms/step - loss: 0.6836 - accuracy: 0.5607 - val_loss: 0.6618 - val_accuracy: 0.6280
# Epoch 2/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6720 - accuracy: 0.6053 - val_loss: 0.6630 - val_accuracy: 0.6280
# Epoch 3/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6710 - accuracy: 0.6053 - val_loss: 0.6608 - val_accuracy: 0.6280
# Epoch 4/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6701 - accuracy: 0.6053 - val_loss: 0.6597 - val_accuracy: 0.6280
# Epoch 5/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6690 - accuracy: 0.6053 - val_loss: 0.6590 - val_accuracy: 0.6280
# Epoch 6/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6673 - accuracy: 0.6080 - val_loss: 0.6566 - val_accuracy: 0.6311
# Epoch 7/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6651 - accuracy: 0.6172 - val_loss: 0.6543 - val_accuracy: 0.6418
# Epoch 8/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6626 - accuracy: 0.6237 - val_loss: 0.6529 - val_accuracy: 0.6463
# Epoch 9/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6615 - accuracy: 0.6302 - val_loss: 0.6517 - val_accuracy: 0.6479
# Epoch 10/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6587 - accuracy: 0.6298 - val_loss: 0.6512 - val_accuracy: 0.6509
# Epoch 11/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6567 - accuracy: 0.6366 - val_loss: 0.6472 - val_accuracy: 0.6479
# Epoch 12/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6541 - accuracy: 0.6374 - val_loss: 0.6472 - val_accuracy: 0.6463
# Epoch 13/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6524 - accuracy: 0.6370 - val_loss: 0.6458 - val_accuracy: 0.6433
# Epoch 14/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6498 - accuracy: 0.6340 - val_loss: 0.6441 - val_accuracy: 0.6509
# Epoch 15/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6493 - accuracy: 0.6324 - val_loss: 0.6401 - val_accuracy: 0.6509
# Epoch 16/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.6397 - val_loss: 0.6368 - val_accuracy: 0.6601
# Epoch 17/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6438 - accuracy: 0.6466 - val_loss: 0.6345 - val_accuracy: 0.6585
# Epoch 18/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6363 - accuracy: 0.6473 - val_loss: 0.6406 - val_accuracy: 0.6631
# Epoch 19/100
# 82/82 [==============================] - 1s 7ms/step - loss: 0.6401 - accuracy: 0.6500 - val_loss: 0.6367 - val_accuracy: 0.6524
# Epoch 20/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6359 - accuracy: 0.6500 - val_loss: 0.6243 - val_accuracy: 0.6631
# Epoch 21/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6511 - val_loss: 0.6262 - val_accuracy: 0.6601
# Epoch 22/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6310 - accuracy: 0.6603 - val_loss: 0.6233 - val_accuracy: 0.6616
# Epoch 23/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6291 - accuracy: 0.6508 - val_loss: 0.6180 - val_accuracy: 0.6570
# Epoch 24/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6288 - accuracy: 0.6557 - val_loss: 0.6240 - val_accuracy: 0.6601
# Epoch 25/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6266 - accuracy: 0.6527 - val_loss: 0.6157 - val_accuracy: 0.6646
# Epoch 26/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6291 - accuracy: 0.6538 - val_loss: 0.6262 - val_accuracy: 0.6555
# Epoch 27/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6279 - accuracy: 0.6527 - val_loss: 0.6218 - val_accuracy: 0.6524
# Epoch 28/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6276 - accuracy: 0.6588 - val_loss: 0.6185 - val_accuracy: 0.6723
# Epoch 29/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6239 - accuracy: 0.6615 - val_loss: 0.6161 - val_accuracy: 0.6677
# Epoch 30/100
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6249 - accuracy: 0.6573 - val_loss: 0.6212 - val_accuracy: 0.6555
# Epoch 31/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6266 - accuracy: 0.6580 - val_loss: 0.6222 - val_accuracy: 0.6616
# Epoch 32/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6227 - accuracy: 0.6595 - val_loss: 0.6135 - val_accuracy: 0.6662
# Epoch 33/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6190 - accuracy: 0.6687 - val_loss: 0.6178 - val_accuracy: 0.6646
# Epoch 34/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6231 - accuracy: 0.6622 - val_loss: 0.6231 - val_accuracy: 0.6662
# Epoch 35/100
# 82/82 [==============================] - 1s 10ms/step - loss: 0.6199 - accuracy: 0.6679 - val_loss: 0.6100 - val_accuracy: 0.6707
# Epoch 36/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6177 - accuracy: 0.6710 - val_loss: 0.6102 - val_accuracy: 0.6646
# Epoch 37/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6197 - accuracy: 0.6664 - val_loss: 0.6167 - val_accuracy: 0.6677
# Epoch 38/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6170 - accuracy: 0.6687 - val_loss: 0.6293 - val_accuracy: 0.6524
# Epoch 39/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6173 - accuracy: 0.6542 - val_loss: 0.6107 - val_accuracy: 0.6631
# Epoch 40/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6174 - accuracy: 0.6615 - val_loss: 0.6081 - val_accuracy: 0.6723
# Epoch 41/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6145 - accuracy: 0.6698 - val_loss: 0.6100 - val_accuracy: 0.6601
# Epoch 42/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6119 - accuracy: 0.6698 - val_loss: 0.6104 - val_accuracy: 0.6707
# Epoch 43/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6097 - accuracy: 0.6740 - val_loss: 0.6053 - val_accuracy: 0.6677
# Epoch 44/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6104 - accuracy: 0.6756 - val_loss: 0.6101 - val_accuracy: 0.6768
# Epoch 45/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6132 - accuracy: 0.6664 - val_loss: 0.6126 - val_accuracy: 0.6646
# Epoch 46/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6081 - accuracy: 0.6779 - val_loss: 0.6150 - val_accuracy: 0.6692
# Epoch 47/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6084 - accuracy: 0.6737 - val_loss: 0.6067 - val_accuracy: 0.6677
# Epoch 48/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.6071 - accuracy: 0.6710 - val_loss: 0.6078 - val_accuracy: 0.6692
# Epoch 49/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6128 - accuracy: 0.6744 - val_loss: 0.6042 - val_accuracy: 0.6738
# Epoch 50/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6034 - accuracy: 0.6760 - val_loss: 0.6045 - val_accuracy: 0.6814
# Epoch 51/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6056 - accuracy: 0.6767 - val_loss: 0.5999 - val_accuracy: 0.6814
# Epoch 52/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6024 - accuracy: 0.6805 - val_loss: 0.6117 - val_accuracy: 0.6601
# Epoch 53/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6050 - accuracy: 0.6809 - val_loss: 0.6122 - val_accuracy: 0.6692
# Epoch 54/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6050 - accuracy: 0.6714 - val_loss: 0.6128 - val_accuracy: 0.6753
# Epoch 55/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.6038 - accuracy: 0.6760 - val_loss: 0.6009 - val_accuracy: 0.6631
# Epoch 56/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6008 - accuracy: 0.6786 - val_loss: 0.6095 - val_accuracy: 0.6707
# Epoch 57/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.6030 - accuracy: 0.6760 - val_loss: 0.6107 - val_accuracy: 0.6768
# Epoch 58/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.5986 - accuracy: 0.6840 - val_loss: 0.6070 - val_accuracy: 0.6692
# Epoch 59/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5989 - accuracy: 0.6756 - val_loss: 0.6026 - val_accuracy: 0.6707
# Epoch 60/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.5977 - accuracy: 0.6767 - val_loss: 0.6092 - val_accuracy: 0.6631
# Epoch 61/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5979 - accuracy: 0.6809 - val_loss: 0.6037 - val_accuracy: 0.6707
# Epoch 62/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5981 - accuracy: 0.6763 - val_loss: 0.6085 - val_accuracy: 0.6616
# Epoch 63/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5949 - accuracy: 0.6870 - val_loss: 0.6036 - val_accuracy: 0.6723
# Epoch 64/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5947 - accuracy: 0.6847 - val_loss: 0.6028 - val_accuracy: 0.6738
# Epoch 65/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.5930 - accuracy: 0.6832 - val_loss: 0.6091 - val_accuracy: 0.6692
# Epoch 66/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.5957 - accuracy: 0.6847 - val_loss: 0.6015 - val_accuracy: 0.6707
# Epoch 67/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.5927 - accuracy: 0.6767 - val_loss: 0.5978 - val_accuracy: 0.6784
# Epoch 68/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5944 - accuracy: 0.6794 - val_loss: 0.6074 - val_accuracy: 0.6723
# Epoch 69/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5932 - accuracy: 0.6855 - val_loss: 0.6098 - val_accuracy: 0.6677
# Epoch 70/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5952 - accuracy: 0.6763 - val_loss: 0.6016 - val_accuracy: 0.6707
# Epoch 71/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5882 - accuracy: 0.6966 - val_loss: 0.6109 - val_accuracy: 0.6707
# Epoch 72/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5929 - accuracy: 0.6866 - val_loss: 0.6026 - val_accuracy: 0.6753
# Epoch 73/100
# 82/82 [==============================] - 1s 15ms/step - loss: 0.5902 - accuracy: 0.6878 - val_loss: 0.6168 - val_accuracy: 0.6692
# Epoch 74/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5947 - accuracy: 0.6855 - val_loss: 0.6031 - val_accuracy: 0.6707
# Epoch 75/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5906 - accuracy: 0.6832 - val_loss: 0.6012 - val_accuracy: 0.6753
# Epoch 76/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5918 - accuracy: 0.6824 - val_loss: 0.6022 - val_accuracy: 0.6829
# Epoch 77/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5906 - accuracy: 0.6901 - val_loss: 0.6022 - val_accuracy: 0.6753
# Epoch 78/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5898 - accuracy: 0.6866 - val_loss: 0.6036 - val_accuracy: 0.6616
# Epoch 79/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5880 - accuracy: 0.6863 - val_loss: 0.6067 - val_accuracy: 0.6738
# Epoch 80/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5869 - accuracy: 0.6908 - val_loss: 0.6011 - val_accuracy: 0.6662
# Epoch 81/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.5848 - accuracy: 0.6882 - val_loss: 0.6221 - val_accuracy: 0.6646
# Epoch 82/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5856 - accuracy: 0.6943 - val_loss: 0.6071 - val_accuracy: 0.6677
# Epoch 83/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.5840 - accuracy: 0.6916 - val_loss: 0.6077 - val_accuracy: 0.6692
# Epoch 84/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.5843 - accuracy: 0.6927 - val_loss: 0.6150 - val_accuracy: 0.6555
# Epoch 85/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5824 - accuracy: 0.6954 - val_loss: 0.6023 - val_accuracy: 0.6753
# Epoch 86/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5821 - accuracy: 0.6958 - val_loss: 0.6061 - val_accuracy: 0.6677
# Epoch 87/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5817 - accuracy: 0.6905 - val_loss: 0.6214 - val_accuracy: 0.6631
# Epoch 88/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5882 - accuracy: 0.6927 - val_loss: 0.6107 - val_accuracy: 0.6631
# Epoch 89/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5837 - accuracy: 0.6893 - val_loss: 0.6152 - val_accuracy: 0.6494
# Epoch 90/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5824 - accuracy: 0.6958 - val_loss: 0.6056 - val_accuracy: 0.6707
# Epoch 91/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5828 - accuracy: 0.6927 - val_loss: 0.6120 - val_accuracy: 0.6662
# Epoch 92/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5839 - accuracy: 0.6889 - val_loss: 0.6088 - val_accuracy: 0.6662
# Epoch 93/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5810 - accuracy: 0.6931 - val_loss: 0.6071 - val_accuracy: 0.6646
# Epoch 94/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.5794 - accuracy: 0.6905 - val_loss: 0.5974 - val_accuracy: 0.6768
# Epoch 95/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.5817 - accuracy: 0.6897 - val_loss: 0.6064 - val_accuracy: 0.6631
# Epoch 96/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5773 - accuracy: 0.6996 - val_loss: 0.6041 - val_accuracy: 0.6753
# Epoch 97/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5767 - accuracy: 0.6947 - val_loss: 0.6017 - val_accuracy: 0.6753
# Epoch 98/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5794 - accuracy: 0.6901 - val_loss: 0.6061 - val_accuracy: 0.6723
# Epoch 99/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5771 - accuracy: 0.7015 - val_loss: 0.6079 - val_accuracy: 0.6662
# Epoch 100/100
# 82/82 [==============================] - 0s 4ms/step - loss: 0.5762 - accuracy: 0.6935 - val_loss: 0.6033 - val_accuracy: 0.6814
# Precisión en el conjunto de prueba: 0.6814024448394775

# %% [markdown]
# # **Modelo 2 - NNM**

# %%
# Modelo de red neuronal
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(8, activation='sigmoid', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(32, activation='elu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(8, activation='selu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(1)
])

# %%
# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Entrenar el modelo
model.fit(X_train, y_train, epochs=500, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.8386 - val_loss: 0.7197
# Epoch 2/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.6513 - val_loss: 0.5865
# Epoch 3/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5397 - val_loss: 0.4962
# Epoch 4/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4636 - val_loss: 0.4323
# Epoch 5/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4111 - val_loss: 0.3900
# Epoch 6/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3740 - val_loss: 0.3581
# Epoch 7/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.3482 - val_loss: 0.3373
# Epoch 8/500
# 64/64 [==============================] - 0s 8ms/step - loss: 0.3283 - val_loss: 0.3200
# Epoch 9/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.3141 - val_loss: 0.3088
# Epoch 10/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3026 - val_loss: 0.2997
# Epoch 11/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2944 - val_loss: 0.2895
# Epoch 12/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2872 - val_loss: 0.2838
# Epoch 13/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2812 - val_loss: 0.2779
# Epoch 14/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2766 - val_loss: 0.2746
# Epoch 15/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2728 - val_loss: 0.2701
# Epoch 16/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2695 - val_loss: 0.2673
# Epoch 17/500
# 64/64 [==============================] - 1s 14ms/step - loss: 0.2667 - val_loss: 0.2646
# Epoch 18/500
# 64/64 [==============================] - 2s 24ms/step - loss: 0.2644 - val_loss: 0.2636
# Epoch 19/500
# 64/64 [==============================] - 1s 16ms/step - loss: 0.2625 - val_loss: 0.2616
# Epoch 20/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2604 - val_loss: 0.2591
# Epoch 21/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2590 - val_loss: 0.2597
# Epoch 22/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2581 - val_loss: 0.2573
# Epoch 23/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2569 - val_loss: 0.2558
# Epoch 24/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2560 - val_loss: 0.2551
# Epoch 25/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2552 - val_loss: 0.2548
# Epoch 26/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2547 - val_loss: 0.2541
# Epoch 27/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2538 - val_loss: 0.2542
# Epoch 28/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2535 - val_loss: 0.2530
# Epoch 29/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2534 - val_loss: 0.2526
# Epoch 30/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2526 - val_loss: 0.2522
# Epoch 31/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2524 - val_loss: 0.2527
# Epoch 32/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2522 - val_loss: 0.2519
# Epoch 33/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2519 - val_loss: 0.2518
# Epoch 34/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2519 - val_loss: 0.2515
# Epoch 35/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2516 - val_loss: 0.2510
# Epoch 36/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2515 - val_loss: 0.2511
# Epoch 37/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2515 - val_loss: 0.2511
# Epoch 38/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2512 - val_loss: 0.2507
# Epoch 39/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2511 - val_loss: 0.2512
# Epoch 40/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2508 - val_loss: 0.2508
# Epoch 41/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2511 - val_loss: 0.2512
# Epoch 42/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2509 - val_loss: 0.2516
# Epoch 43/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2510 - val_loss: 0.2514
# Epoch 44/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2511 - val_loss: 0.2512
# Epoch 45/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2507 - val_loss: 0.2509
# Epoch 46/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2511
# Epoch 47/500
# 64/64 [==============================] - 0s 8ms/step - loss: 0.2508 - val_loss: 0.2504
# Epoch 48/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2509 - val_loss: 0.2499
# Epoch 49/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2507
# Epoch 50/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 51/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 52/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2500
# Epoch 53/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2508
# Epoch 54/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 55/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2504 - val_loss: 0.2499
# Epoch 56/500
# 64/64 [==============================] - 1s 11ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 57/500
# 64/64 [==============================] - 1s 12ms/step - loss: 0.2503 - val_loss: 0.2506
# Epoch 58/500
# 64/64 [==============================] - 2s 23ms/step - loss: 0.2508 - val_loss: 0.2516
# Epoch 59/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 60/500
# 64/64 [==============================] - 1s 11ms/step - loss: 0.2501 - val_loss: 0.2531
# Epoch 61/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2505 - val_loss: 0.2498
# Epoch 62/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2497
# Epoch 63/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2503
# Epoch 64/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2498
# Epoch 65/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2507 - val_loss: 0.2497
# Epoch 66/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2507 - val_loss: 0.2500
# Epoch 67/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 68/500
# 64/64 [==============================] - 2s 25ms/step - loss: 0.2505 - val_loss: 0.2502
# Epoch 69/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2505 - val_loss: 0.2500
# Epoch 70/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 71/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2505 - val_loss: 0.2514
# Epoch 72/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 73/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2504 - val_loss: 0.2506
# Epoch 74/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2517
# Epoch 75/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2498
# Epoch 76/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 77/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2505 - val_loss: 0.2499
# Epoch 78/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2501 - val_loss: 0.2497
# Epoch 79/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2513
# Epoch 80/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 81/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2511 - val_loss: 0.2509
# Epoch 82/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2497
# Epoch 83/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2508
# Epoch 84/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2506
# Epoch 85/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2497
# Epoch 86/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 87/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 88/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2512
# Epoch 89/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2498
# Epoch 90/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2504 - val_loss: 0.2500
# Epoch 91/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2502 - val_loss: 0.2507
# Epoch 92/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 93/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2500
# Epoch 94/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 95/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 96/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 97/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2497
# Epoch 98/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2506 - val_loss: 0.2500
# Epoch 99/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2498
# Epoch 100/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 101/500
# 64/64 [==============================] - 1s 10ms/step - loss: 0.2507 - val_loss: 0.2497
# Epoch 102/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 103/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2515
# Epoch 104/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 105/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2507 - val_loss: 0.2507
# Epoch 106/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2508
# Epoch 107/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2521
# Epoch 108/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2499
# Epoch 109/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 110/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 111/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 112/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 113/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2504 - val_loss: 0.2497
# Epoch 114/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 115/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 116/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 117/500
# 64/64 [==============================] - 0s 8ms/step - loss: 0.2509 - val_loss: 0.2509
# Epoch 118/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2506
# Epoch 119/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 120/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2508
# Epoch 121/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 122/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2506
# Epoch 123/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 124/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 125/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 126/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 127/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 128/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 129/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2514 - val_loss: 0.2498
# Epoch 130/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2502
# Epoch 131/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2505 - val_loss: 0.2501
# Epoch 132/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2501 - val_loss: 0.2525
# Epoch 133/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2504 - val_loss: 0.2499
# Epoch 134/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2500 - val_loss: 0.2511
# Epoch 135/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2505 - val_loss: 0.2499
# Epoch 136/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2501 - val_loss: 0.2499
# Epoch 137/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2502 - val_loss: 0.2510
# Epoch 138/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2505
# Epoch 139/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2506
# Epoch 140/500
# 64/64 [==============================] - 1s 10ms/step - loss: 0.2507 - val_loss: 0.2513
# Epoch 141/500
# 64/64 [==============================] - 1s 19ms/step - loss: 0.2501 - val_loss: 0.2500
# Epoch 142/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 143/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2501 - val_loss: 0.2513
# Epoch 144/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2505 - val_loss: 0.2499
# Epoch 145/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 146/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 147/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 148/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 149/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2505
# Epoch 150/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2501 - val_loss: 0.2499
# Epoch 151/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 152/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2499
# Epoch 153/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2507
# Epoch 154/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2510 - val_loss: 0.2516
# Epoch 155/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2507 - val_loss: 0.2504
# Epoch 156/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 157/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2500
# Epoch 158/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 159/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2514
# Epoch 160/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2502
# Epoch 161/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 162/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2500
# Epoch 163/500
# 64/64 [==============================] - 0s 8ms/step - loss: 0.2501 - val_loss: 0.2520
# Epoch 164/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2500 - val_loss: 0.2497
# Epoch 165/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 166/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2504
# Epoch 167/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2511
# Epoch 168/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 169/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 170/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 171/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2506
# Epoch 172/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2502
# Epoch 173/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2508
# Epoch 174/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 175/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2514
# Epoch 176/500
# 64/64 [==============================] - 1s 10ms/step - loss: 0.2504 - val_loss: 0.2504
# Epoch 177/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 178/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 179/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2504 - val_loss: 0.2514
# Epoch 180/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2501
# Epoch 181/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2512
# Epoch 182/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2507
# Epoch 183/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 184/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 185/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 186/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 187/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 188/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2504
# Epoch 189/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2502 - val_loss: 0.2497
# Epoch 190/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2504 - val_loss: 0.2502
# Epoch 191/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 192/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2507
# Epoch 193/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2506
# Epoch 194/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2499
# Epoch 195/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2500
# Epoch 196/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 197/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 198/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 199/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 200/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 201/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 202/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2507
# Epoch 203/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 204/500
# 64/64 [==============================] - 1s 11ms/step - loss: 0.2501 - val_loss: 0.2498
# Epoch 205/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2499
# Epoch 206/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2497
# Epoch 207/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2505 - val_loss: 0.2500
# Epoch 208/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 209/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2507 - val_loss: 0.2499
# Epoch 210/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2505 - val_loss: 0.2499
# Epoch 211/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2507
# Epoch 212/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 213/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2507
# Epoch 214/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2497
# Epoch 215/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2498
# Epoch 216/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2511
# Epoch 217/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2507
# Epoch 218/500
# 64/64 [==============================] - 1s 14ms/step - loss: 0.2501 - val_loss: 0.2497
# Epoch 219/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 220/500
# 64/64 [==============================] - 1s 13ms/step - loss: 0.2502 - val_loss: 0.2507
# Epoch 221/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2507
# Epoch 222/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 223/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 224/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2515
# Epoch 225/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 226/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 227/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2507
# Epoch 228/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 229/500
# 64/64 [==============================] - 1s 11ms/step - loss: 0.2502 - val_loss: 0.2506
# Epoch 230/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2503 - val_loss: 0.2509
# Epoch 231/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 232/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2506 - val_loss: 0.2512
# Epoch 233/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 234/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2506
# Epoch 235/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 236/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 237/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 238/500
# 64/64 [==============================] - 1s 20ms/step - loss: 0.2504 - val_loss: 0.2499
# Epoch 239/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 240/500
# 64/64 [==============================] - 1s 13ms/step - loss: 0.2502 - val_loss: 0.2507
# Epoch 241/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 242/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2503 - val_loss: 0.2506
# Epoch 243/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2502 - val_loss: 0.2506
# Epoch 244/500
# 64/64 [==============================] - 1s 20ms/step - loss: 0.2504 - val_loss: 0.2502
# Epoch 245/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 246/500
# 64/64 [==============================] - 0s 8ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 247/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2502 - val_loss: 0.2497
# Epoch 248/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2509 - val_loss: 0.2497
# Epoch 249/500
# 64/64 [==============================] - 1s 11ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 250/500
# 64/64 [==============================] - 2s 24ms/step - loss: 0.2502 - val_loss: 0.2497
# Epoch 251/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2504 - val_loss: 0.2503
# Epoch 252/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 253/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 254/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2502 - val_loss: 0.2512
# Epoch 255/500
# 64/64 [==============================] - 1s 18ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 256/500
# 64/64 [==============================] - 1s 11ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 257/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2506 - val_loss: 0.2501
# Epoch 258/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2501 - val_loss: 0.2501
# Epoch 259/500
# 64/64 [==============================] - 1s 12ms/step - loss: 0.2501 - val_loss: 0.2506
# Epoch 260/500
# 64/64 [==============================] - 1s 15ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 261/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 262/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2509
# Epoch 263/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2500 - val_loss: 0.2502
# Epoch 264/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 265/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2501 - val_loss: 0.2508
# Epoch 266/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 267/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 268/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 269/500
# 64/64 [==============================] - 1s 18ms/step - loss: 0.2504 - val_loss: 0.2499
# Epoch 270/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2507
# Epoch 271/500
# 64/64 [==============================] - 1s 12ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 272/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 273/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 274/500
# 64/64 [==============================] - 1s 9ms/step - loss: 0.2501 - val_loss: 0.2512
# Epoch 275/500
# 64/64 [==============================] - 1s 14ms/step - loss: 0.2501 - val_loss: 0.2497
# Epoch 276/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2501 - val_loss: 0.2512
# Epoch 277/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 278/500
# 64/64 [==============================] - 2s 32ms/step - loss: 0.2503 - val_loss: 0.2515
# Epoch 279/500
# 64/64 [==============================] - 1s 15ms/step - loss: 0.2509 - val_loss: 0.2510
# Epoch 280/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 281/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2500
# Epoch 282/500
# 64/64 [==============================] - 1s 10ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 283/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2505 - val_loss: 0.2500
# Epoch 284/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 285/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2505
# Epoch 286/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 287/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 288/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2501 - val_loss: 0.2500
# Epoch 289/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2499 - val_loss: 0.2512
# Epoch 290/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 291/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2500
# Epoch 292/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 293/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 294/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 295/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2497
# Epoch 296/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 297/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 298/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 299/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 300/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2503
# Epoch 301/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 302/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2503
# Epoch 303/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2513
# Epoch 304/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2505
# Epoch 305/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 306/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 307/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2500
# Epoch 308/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2501 - val_loss: 0.2507
# Epoch 309/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2502
# Epoch 310/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 311/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 312/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 313/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 314/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 315/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2500 - val_loss: 0.2505
# Epoch 316/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2499
# Epoch 317/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 318/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 319/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2499
# Epoch 320/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2497
# Epoch 321/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2507 - val_loss: 0.2506
# Epoch 322/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2505 - val_loss: 0.2509
# Epoch 323/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 324/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 325/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2510
# Epoch 326/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2503
# Epoch 327/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 328/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2506
# Epoch 329/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 330/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 331/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2506
# Epoch 332/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2497
# Epoch 333/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2511
# Epoch 334/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 335/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 336/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 337/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2507
# Epoch 338/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 339/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2510
# Epoch 340/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 341/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2506
# Epoch 342/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 343/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 344/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 345/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2502
# Epoch 346/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 347/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 348/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2506
# Epoch 349/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2501 - val_loss: 0.2510
# Epoch 350/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 351/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 352/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 353/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2510
# Epoch 354/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2500 - val_loss: 0.2500
# Epoch 355/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 356/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2507
# Epoch 357/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 358/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 359/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2501 - val_loss: 0.2509
# Epoch 360/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 361/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 362/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 363/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 364/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 365/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 366/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2498
# Epoch 367/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2505
# Epoch 368/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 369/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 370/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 371/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2504 - val_loss: 0.2501
# Epoch 372/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2508 - val_loss: 0.2505
# Epoch 373/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 374/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2504
# Epoch 375/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2506
# Epoch 376/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 377/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 378/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2498
# Epoch 379/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2506 - val_loss: 0.2500
# Epoch 380/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 381/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2500
# Epoch 382/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2506 - val_loss: 0.2501
# Epoch 383/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2505
# Epoch 384/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2498
# Epoch 385/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 386/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 387/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 388/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 389/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 390/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2504
# Epoch 391/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 392/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 393/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 394/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 395/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2499
# Epoch 396/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 397/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2515
# Epoch 398/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2510
# Epoch 399/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2505 - val_loss: 0.2511
# Epoch 400/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2502
# Epoch 401/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 402/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2509 - val_loss: 0.2498
# Epoch 403/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2500 - val_loss: 0.2519
# Epoch 404/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2499
# Epoch 405/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 406/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 407/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 408/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2503 - val_loss: 0.2502
# Epoch 409/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2510
# Epoch 410/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 411/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 412/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2515
# Epoch 413/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 414/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 415/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2501
# Epoch 416/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2500 - val_loss: 0.2497
# Epoch 417/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2503 - val_loss: 0.2501
# Epoch 418/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2514
# Epoch 419/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 420/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 421/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2497
# Epoch 422/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2502
# Epoch 423/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 424/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 425/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 426/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2501 - val_loss: 0.2504
# Epoch 427/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 428/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2509
# Epoch 429/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 430/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2508
# Epoch 431/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 432/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2501
# Epoch 433/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2505
# Epoch 434/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2497
# Epoch 435/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 436/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2501 - val_loss: 0.2504
# Epoch 437/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2502
# Epoch 438/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2519
# Epoch 439/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2505
# Epoch 440/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2498
# Epoch 441/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2497
# Epoch 442/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2508
# Epoch 443/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2513
# Epoch 444/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 445/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 446/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 447/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2500 - val_loss: 0.2503
# Epoch 448/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 449/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2510
# Epoch 450/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2503
# Epoch 451/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2502
# Epoch 452/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2507 - val_loss: 0.2502
# Epoch 453/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2502
# Epoch 454/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 455/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2508
# Epoch 456/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 457/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 458/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2503
# Epoch 459/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2511
# Epoch 460/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2504
# Epoch 461/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 462/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2501
# Epoch 463/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 464/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2509
# Epoch 465/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2498
# Epoch 466/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 467/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2498
# Epoch 468/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2508
# Epoch 469/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2503
# Epoch 470/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.2502 - val_loss: 0.2511
# Epoch 471/500
# 64/64 [==============================] - 1s 8ms/step - loss: 0.2504 - val_loss: 0.2508
# Epoch 472/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2501 - val_loss: 0.2500
# Epoch 473/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2507
# Epoch 474/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2505 - val_loss: 0.2501
# Epoch 475/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2500
# Epoch 476/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2500
# Epoch 477/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 478/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2503 - val_loss: 0.2502
# Epoch 479/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.2503 - val_loss: 0.2507
# Epoch 480/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2498
# Epoch 481/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2501
# Epoch 482/500
# 64/64 [==============================] - 0s 8ms/step - loss: 0.2501 - val_loss: 0.2500
# Epoch 483/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 484/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2505
# Epoch 485/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2504
# Epoch 486/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2502 - val_loss: 0.2503
# Epoch 487/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.2501 - val_loss: 0.2498
# Epoch 488/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2504 - val_loss: 0.2507
# Epoch 489/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.2503
# Epoch 490/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2500
# Epoch 491/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2499
# Epoch 492/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.2499
# Epoch 493/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 494/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2502 - val_loss: 0.2502
# Epoch 495/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2503
# Epoch 496/500
# 64/64 [==============================] - 0s 8ms/step - loss: 0.2501 - val_loss: 0.2500
# Epoch 497/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.2508
# Epoch 498/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2505 - val_loss: 0.2511
# Epoch 499/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.2501
# Epoch 500/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2497

# %%
# Evaluar el modelo
Y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, Y_pred)
mae = mean_absolute_error(y_test, Y_pred)
print("MSE:", mse)
print("MAE:", mae)
# Out:
# 16/16 [==============================] - 0s 2ms/step
# MSE: 0.24970154358312957
# MAE: 0.4994961229385808

# %%
mide_error('MLP', Y_pred)
# Out:
# MLP AUC: 0.5000
